# %%
from research import create_and_compile_graph
import os
from api_keys import langsmith_api_key
import warnings

graph = create_and_compile_graph()

# %%
graph

# %%
os.environ["LANGSMITH_API_KEY"] = langsmith_api_key
os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_PROJECT"] = "default"

result = graph.invoke(
    {
        "ticker": "SHCO",
        "company_name": "Soho House",
        "company_sector": "Hospitality"
    },
    config={"recursion_limit": 250}
)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[3], line 5
#       2 os.environ["LANGSMITH_TRACING"] = "true"
#       3 os.environ["LANGSMITH_PROJECT"] = "default"
# ----> 5 result = graph.invoke(
#       6     {
#       7         "ticker": "SHCO",
#       8         "company_name": "Soho House",
#       9         "company_sector": "Hospitality"
#      10     },
#      11     config={"recursion_limit": 250}
#      12 )
#
# File c:\Users\tom.smith\AppData\Local\anaconda3\envs\stock-selection\Lib\site-packages\langgraph\pregel\main.py:3094, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3091 chunks: list[dict[str, Any] | Any] = []
#    3092 interrupts: list[Interrupt] = []
# -> 3094 for chunk in self.stream(
#    3095     input,
#    3096     config,
# ...

# %%
print(result['research_output'].research_output)
# Out:
# 1. Company Overview
# Soho House & Co (NYSE: SHCO) has agreed to be taken private at $9.00/share by a buyer group led by MCR, with major existing holders (Yucaipa/Ron Burkle, founder Nick Jones, Goldman Sachs Alternatives) rolling/retaining stakes and Apollo providing hybrid capital. The merger requires (i) a majority of the voting power of the outstanding Common Stock (Class A and Class B voting together) and (ii) a majority of votes cast by Unaffiliated Stockholders. Sources: PREM14A (Accession 0001140361‑25‑035706) and Schedule 13E‑3 (Accession 0001140361‑25‑035726).
#
# 2. Recent Developments
# Definitive agreements were signed Aug 15, 2025; announced Aug 18, 2025. Preliminary proxy (PREM14A) and Schedule 13E‑3 were filed Sep 22, 2025. As of Oct 26, 2025, no DEFM14A (definitive proxy) or additional 14A‑series materials were posted in Oct. Antitrust risk is reduced by FTC HSR early termination references; financing commitments are described in annexes to the proxy/13E‑3.
#
# ...
